# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Getting the data**

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"

# %%
response = requests.get(data_url)
columns = [x.split()[0] for x in response.text.split('\n')[7:21]]

# %%
data = response.text.split('\n')[22:-1]

# %%
new_data = []
for row in range(0, len(data), 2):
    row_data = data[row] + data[row+1]
    row_data = list(map(float, row_data.split()))
    new_data.append(row_data)

# %%
boston_df = pd.DataFrame(new_data, columns=columns)

# %% [markdown]
# ## **EDA**

# %%
boston_df = boston_df.rename(columns={'MEDV': 'Price'})

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
import seaborn as sns

correlation_matrix = boston_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Boston Housing Dataset')
plt.show()

# %%
sns.regplot(x=boston_df['RM'], y=boston_df['Price'])
# Out:
# <Axes: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x=boston_df['LSTAT'], y=boston_df['Price'])
# Out:
# <Axes: xlabel='LSTAT', ylabel='Price'>

# %%
sns.regplot(x=boston_df['PTRATIO'], y=boston_df['Price'])
# Out:
# <Axes: xlabel='PTRATIO', ylabel='Price'>

# %% [markdown]
# ## **Independent and dependent features**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = boston_df.iloc[:, :-1]
y = boston_df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## **Model training**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_error

# %%
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([-1.10834602,  0.80843998,  0.34313466,  0.81386426, -1.79804295,
#         2.913858  , -0.29893918, -2.94251148,  2.09419303, -1.44706731,
#        -2.05232232,  1.02375187, -3.88579002])

# %%
regression.intercept_
# Out:
# 23.01581920903955

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
reg_pred = regression.predict(X_test)

# %%
mean_absolute_error(y_test, reg_pred)
# Out:
# 3.1627098714574053

# %%
root_mean_squared_error(y_test, reg_pred)
# Out:
# 4.6386899261728205

# %%
plt.scatter(y_test, reg_pred)

# %%
r2_score(y_test, reg_pred)
# Out:
# 0.7112260057484932

# %%
residuals = y_test - reg_pred

# %%
sns.displot(residuals, kind='kde')

# %%
plt.scatter(reg_pred, residuals)

# %%
r2_score(reg_pred, y_test)
# Out:
# 0.6693702691495593

# %% [markdown]
# ## **New data prediction**

# %%
regression.predict(X_test[3].reshape(1, -1))
# Out:
# array([25.40321303])

# %%
reg_pred[3]
# Out:
# 25.403213033778915

# %%
y_test.iloc[3]
# Out:
# 22.8

# %% [markdown]
# ## **Pickling the model file for deployment**

# %%
import pickle

# %%
pickle.dump(regression, open('/content/gdrive/MyDrive/Projects/end_to_end_tutorial/reg_model.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('/content/gdrive/MyDrive/Projects/end_to_end_tutorial/reg_model.pkl', 'rb'))
